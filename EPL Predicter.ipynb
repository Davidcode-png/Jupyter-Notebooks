# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
match_df = pd.read_csv(r'matches.csv',index_col=0)

# %%
match_df.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
match_df.shape
# Out:
# (1520, 27)

# %%
match_df['team'].value_counts()
# Out:
# Manchester City             76
# Wolverhampton Wanderers     76
# Burnley                     76
# Leeds United                76
# Everton                     76
# Southampton                 76
# Aston Villa                 76
# Liverpool                   76
# Newcastle United            76
# Crystal Palace              76
# Brighton and Hove Albion    76
# Leicester City              76
# West Ham United             76
# Manchester United           76
# Arsenal                     76
# Tottenham Hotspur           76
# Chelsea                     76
# Brentford                   38
# Watford                     38
# Norwich City                38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Name: team, dtype: int64

# %%
match_df['date'] = pd.to_datetime(match_df['date'])

# %%
match_df.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
match_df['venue_code'] = match_df["venue"].astype("category").cat.codes

# %%
match_df.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1       Tottenham  ...    NaN  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2    Norwich City  ...    NaN  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3         Arsenal  ...    NaN  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4  Leicester City  ...    NaN  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6     Southampton  ...    NaN  16.0   1.0  15.7  1.0  0.0   0.0   2022
#
#               team  venue_code
# 1  Manchester City           0
# ...

# %%
match_df['opp_code'] = match_df['opponent'].astype("category").cat.codes

# %%
match_df.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1       Tottenham  ...  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2    Norwich City  ...  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3         Arsenal  ...  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4  Leicester City  ...  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6     Southampton  ...  16.0   1.0  15.7  1.0  0.0   0.0   2022
#
#               team  venue_code  opp_code
# 1  Manchester City           0        18
# 2  Manchester City           1        15
# ...

# %%
match_df['hour'] = match_df['time'].str.replace(":.+","",regex=True).astype("int")

# %%
match_df.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...   sot  dist   fk   pk pkatt season             team  \
# 1       Tottenham  ...   4.0  16.9  1.0  0.0   0.0   2022  Manchester City
# 2    Norwich City  ...   4.0  17.3  1.0  0.0   0.0   2022  Manchester City
# 3         Arsenal  ...  10.0  14.3  0.0  0.0   0.0   2022  Manchester City
# 4  Leicester City  ...   8.0  14.0  0.0  0.0   0.0   2022  Manchester City
# 6     Southampton  ...   1.0  15.7  1.0  0.0   0.0   2022  Manchester City
#
#   venue_code  opp_code  hour
# 1          0        18    16
# ...

# %%
match_df['day_code'] = match_df['date'].dt.dayofweek

# %%
match_df.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  dist   fk   pk  pkatt season             team  \
# 1       Tottenham  ...  16.9  1.0  0.0    0.0   2022  Manchester City
# 2    Norwich City  ...  17.3  1.0  0.0    0.0   2022  Manchester City
# 3         Arsenal  ...  14.3  0.0  0.0    0.0   2022  Manchester City
# 4  Leicester City  ...  14.0  0.0  0.0    0.0   2022  Manchester City
# 6     Southampton  ...  15.7  1.0  0.0    0.0   2022  Manchester City
#
#   venue_code opp_code  hour  day_code
# 1          0       18    16         6
# ...

# %%
match_df["target"] = (match_df['result'] == 'W').astype("int")

# %%
match_df.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  target
# ...

# %%
# match_df['target2'] = match_df['result'].astype('category').cat.codes

# %%
match_df
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
# ...

# %%
rf = RandomForestClassifier(n_estimators=50,min_samples_split=10,random_state=1)

# %% [markdown]
# ## Using Last year's data to predict this year's scores

# %%
train = match_df[match_df['date'] < "2022-01-01"]
test = match_df[match_df['date'] > "2022-01-01"]

# %%
predictors = ['venue_code','opp_code','hour','day_code']

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
prediction = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(test['target'],prediction)

# %%
accuracy
# Out:
# 0.6056701030927835

# %%
combined = pd.DataFrame(dict(actual=test['target'],predictions=prediction))

# %%
pd.crosstab(index=combined['actual'],columns=combined['predictions'])
# Out:
# predictions    0   1
# actual
# 0            186  47
# 1            106  49

# %%
grouped_matches = match_df.groupby('team')

# %%
group = grouped_matches.get_group('Manchester City')

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W   2   0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L   1   2
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W   4   3
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L   2   3
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   5   0
#
# ...

# %%
def rolling_average(group,cols,new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3,closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf','ga','sh','sot','dist','fk','pk','pkatt']
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_average(group,cols,new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D   1   1
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L   0   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away      W   4   0
# 54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home      W   5   0
# 55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away      W   5   1
# 56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D   2   2
# 57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      W   3   2
#
# ...

# %%
match_rolling = match_df.groupby('team').apply(lambda x: rolling_average(x,cols,new_cols))

# %%
match_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 37 2022-04-30  15:00  Premier League  Matchweek 35
#                         38 2022-05-07  15:00  Premier League  Matchweek 36
#                         39 2022-05-11  20:15  Premier League  Matchweek 33
#                         40 2022-05-15  14:00  Premier League  Matchweek 37
#                         41 2022-05-22  16:00  Premier League  Matchweek 38
#
# ...

# %%
match_rolling = match_rolling.droplevel('team')

# %%
match_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 6  2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2   1
# 7  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0   1
# 9  2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0   1
# 11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1   0
# 13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 37 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0   3
# 38 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2   2
# 39 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1   5
# 40 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1   1
# 41 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1   3
#
# ...

# %%
match_rolling.index = range(match_rolling.shape[0])

# %%
match_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 1443 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0
# 1444 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2
# 1445 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1
# 1446 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1
# 1447 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1
#
# ...

# %%
from sklearn.metrics import precision_score

# %%
def makepredictions(data,predictors):
    train = data[data['date'] < "2022-01-01"]
    test = data[data['date'] > "2022-01-01"]
    rf.fit(train[predictors], train["target"])
    prediction = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'],predictions=prediction))
    precision = precision_score(test['target'],prediction)
    return combined,precision

# %%
combined, precision = makepredictions(match_rolling,predictors+new_cols)

# %%
precision
# Out:
# 0.6027397260273972

# %%
pd.crosstab(index=combined['actual'],columns=combined['predictions'])
# Out:
# predictions    0   1
# actual
# 0            204  29
# 1            111  44

# %%
combined = combined.merge(match_rolling[['date','team','opponent','result']] , left_index = True,right_index=True)

# %%
combined
# Out:
#       actual  predictions       date                     team  \
# 55         0            0 2022-01-23                  Arsenal
# 56         1            1 2022-02-10                  Arsenal
# 57         1            0 2022-02-19                  Arsenal
# 58         1            1 2022-02-24                  Arsenal
# 59         1            1 2022-03-06                  Arsenal
# ...      ...          ...        ...                      ...
# 1443       0            0 2022-04-30  Wolverhampton Wanderers
# 1444       0            0 2022-05-07  Wolverhampton Wanderers
# 1445       0            0 2022-05-11  Wolverhampton Wanderers
# 1446       0            0 2022-05-15  Wolverhampton Wanderers
# 1447       0            0 2022-05-22  Wolverhampton Wanderers
#
#              opponent result
# 55            Burnley      D
# 56             Wolves      W
# 57          Brentford      W
# 58             Wolves      W
# 59            Watford      W
# ...               ...    ...
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
map_values = {
    'Brighton and Hove Albion':'Brighton',
    'Manchester United':'Manchester Utd',
    'Newcastle United': 'Newcastle Utd',
    'Tottenham Hotsput': 'Tottenham',
    'West Ham United': 'West Ham',
    'Wolverhampton Wanderers':'Wolves'
}

mapping = MissingDict(**map_values)

# %%
mapping['West Ham United']
# Out:
# 'West Ham'

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined
# Out:
#       actual  predictions       date                     team  \
# 55         0            0 2022-01-23                  Arsenal
# 56         1            1 2022-02-10                  Arsenal
# 57         1            0 2022-02-19                  Arsenal
# 58         1            1 2022-02-24                  Arsenal
# 59         1            1 2022-03-06                  Arsenal
# ...      ...          ...        ...                      ...
# 1443       0            0 2022-04-30  Wolverhampton Wanderers
# 1444       0            0 2022-05-07  Wolverhampton Wanderers
# 1445       0            0 2022-05-11  Wolverhampton Wanderers
# 1446       0            0 2022-05-15  Wolverhampton Wanderers
# 1447       0            0 2022-05-22  Wolverhampton Wanderers
#
#              opponent result new_team
# 55            Burnley      D  Arsenal
# 56             Wolves      W  Arsenal
# 57          Brentford      W  Arsenal
# 58             Wolves      W  Arsenal
# ...

# %%
merged = combined.merge(combined,left_on=['date','new_team'],right_on=['date','opponent'])

# %%
merged
# Out:
#      actual_x  predictions_x       date                   team_x  \
# 0           0              0 2022-01-23                  Arsenal
# 1           1              1 2022-02-10                  Arsenal
# 2           1              0 2022-02-19                  Arsenal
# 3           1              1 2022-02-24                  Arsenal
# 4           1              1 2022-03-06                  Arsenal
# ..        ...            ...        ...                      ...
# 363         0              0 2022-04-30  Wolverhampton Wanderers
# 364         0              0 2022-05-07  Wolverhampton Wanderers
# 365         0              0 2022-05-11  Wolverhampton Wanderers
# 366         0              0 2022-05-15  Wolverhampton Wanderers
# 367         0              0 2022-05-22  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predictions_y  \
# 0            Burnley        D    Arsenal         0              0
# ...

# %%
merged[(merged['predictions_x'] == 1) & (merged['predictions_y'] == 0)]['actual_x'].value_counts()
# Out:
# 1    38
# 0    26
# Name: actual_x, dtype: int64

# %%
38/(38+26)
# Out:
# 0.59375
